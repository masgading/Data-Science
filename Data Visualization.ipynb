# %%
import sys
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install lxml
import requests
import lxml.html as lh
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: requests in c:\users\sectio\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sectio\anaconda3\lib\site-packages (from requests) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sectio\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sectio\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sectio\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: lxml in c:\users\sectio\anaconda3\lib\site-packages (4.5.2)

# %%
url='http://pokemondb.net/pokedex/all'
page = requests.get(url)
doc = lh.fromstring(page.content)
tr_elements = doc.xpath('//tr')

# %%
[len(Z) for Z in tr_elements[:8]]
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10]

# %%
#menguraikan tabel
tr_elements = doc.xpath('//tr')
col=[]
i=0
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"#"
# 2:"Name"
# 3:"Type"
# 4:"Total"
# 5:"HP"
# 6:"Attack"
# 7:"Defense"
# 8:"Sp. Atk"
# 9:"Sp. Def"
# 10:"Speed"

# %%
#mengubah tipe data ke dalam tuple
for j in range(1,len(tr_elements)):
    T=tr_elements[j] 
    if len(T)!=10:
        break
    i=0

    for t in T.iterchildren():
        data=t.text_content() 
        if i>0:
            try:
                data=int(data)
            except:
                pass
        col[i][1].append(data)
        i+=1

# %%
#mengetahui jumlah baris
[len(B) for (title,B) in col]
# Out:
# [1045, 1045, 1045, 1045, 1045, 1045, 1045, 1045, 1045, 1045]

# %%
# mengubah ke Dictionary , lalu buat dataframe dari dictionary
Dict={title:column for (title,column) in col}
data=pd.DataFrame(Dict)

# %%
#menampilkan data
data.head()
# Out:
#      #                    Name          Type  Total  HP  Attack  Defense  \
# 0  001               Bulbasaur  Grass Poison    318  45      49       49
# 1  002                 Ivysaur  Grass Poison    405  60      62       63
# 2  003                Venusaur  Grass Poison    525  80      82       83
# 3  003  Venusaur Mega Venusaur  Grass Poison    625  80     100      123
# 4  004              Charmander         Fire     309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed
# 0       65       65     45
# 1       80       80     60
# 2      100      100     80
# 3      122      120     80
# 4       60       50     65

# %%
#dimensi data frame
data.shape
# Out:
# (1045, 10)

# %%
#deskripsi kolom
data.describe()
# Out:
#              Total           HP       Attack      Defense      Sp. Atk  \
# count  1045.000000  1045.000000  1045.000000  1045.000000  1045.000000
# mean    439.314833    70.067943    80.466986    74.661244    73.022010
# std     121.970701    26.671411    32.413665    31.237903    32.724797
# min     175.000000     1.000000     5.000000     5.000000    10.000000
# 25%     330.000000    50.000000    55.000000    50.000000    50.000000
# 50%     458.000000    68.000000    77.000000    70.000000    65.000000
# 75%     515.000000    82.000000   100.000000    90.000000    95.000000
# max    1125.000000   255.000000   190.000000   250.000000   194.000000
#
#            Sp. Def        Speed
# count  1045.000000  1045.000000
# mean     72.288995    68.807656
# std      28.074148    30.210094
# min      20.000000     5.000000
# 25%      50.000000    45.000000
# 50%      70.000000    65.000000
# 75%      90.000000    90.000000
# max     250.000000   200.000000

# %%
#visulaisasi data anatra Hp and Attack
data.plot.scatter('HP','Attack')

# %%
#visualisasi scatter plot antara HP dan Defence
data.plot(x = "HP", y = "Defense", style = "^")
plt.title("Pengaruh HP terhadap Defense")
plt.xlabel("Darah Karakter")
plt.ylabel("Defense Karakter")
plt.show()

# %%
data.plot(x = "Attack", y = "Defense", style = "^")
plt.title("Pengaruh Attack terhadap Defense")
plt.xlabel("Attack")
plt.ylabel("Defense Karakter")
plt.show()

# %%
data.plot(x = "Attack", y = "Speed", style = "^")
plt.title("Pengaruh Attack terhadap Speed")
plt.xlabel("Attack")
plt.ylabel("Speed")
plt.show()

# %%
data.plot(x = "Attack", y = "Sp. Atk", style = ".")
plt.title("Pengaruh Attack terhadap Sp. Atk")
plt.xlabel("Attack")
plt.ylabel("Sp. Atk")
plt.show()

# %%
data.plot(x = "Attack", y = "Sp. Def", style = ".")
plt.title("Pengaruh Attack terhadap Sp. Def")
plt.xlabel("Attack")
plt.ylabel("Sp. Def")
plt.show()
